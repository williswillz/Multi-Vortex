# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.mlab import psd

# %% [markdown]
# ### NACA 4 digit airfoil generator

# %%
def naca_airfoil(code, num_points, zero_thick_te=False, uniform=False):
    """Return a NACA 4-digit series airfoil"""
    # extract parameters from 4-digit code
    code_str = "%04d" % int(code)
    if len(code_str) != 4:
        raise ValueError("NACA designation is more than 4 digits")
    max_camber = 0.01 * int(code_str[0])
    p = 0.1 * int(code_str[1])  # location of max camber
    thickness = 0.01 * int(code_str[2:])
    if uniform:
        x = np.linspace(0, 1, num_points)
    else:
        # closer spacing near leading edge
        theta = np.linspace(0, 0.5 * np.pi, num_points)
        x = 1 - np.cos(theta)

    # thickness
    coefs = [-0.1015, 0.2843, -0.3516, -0.1260, 0, 0.2969]
    if zero_thick_te:
        coefs[0] = -0.1036
    y_thick = 5 * thickness * (np.polyval(coefs[:5], x) +
                               coefs[5] * np.sqrt(x))

    # camber
    front = np.where(x <= p)
    back = np.where(x > p)
    y_camber = np.zeros_like(x)
    if p:
        y_camber[front] = max_camber * x[front] / p**2 * (2 * p - x[front])
        y_camber[back] = max_camber * ((1. - x[back])/(1. - p)**2 *
                                       (1 + x[back] - 2 * p))
    x = np.hstack([x[-1:0:-1], x])
    y = np.hstack([y_camber[-1:0:-1] + y_thick[-1:0:-1],
                   y_camber - y_thick])
    return (np.array([x, y]).T)

# %% [markdown]
# ### Declaring a variable to store cooridnates of airfoil

# %%
q = naca_airfoil(0012, 101)

# %% [markdown]
# ### Collacation point (obervations point on the airfoil where the vortex influence will be captured)

# %%
q_mid = (q[1:] + q[:-1])/2

# %% [markdown]
# ### Defining the computational domain where the vortices are distributed

# %%
length = 100. #nondimensional length of window
height = 0.2 #window height
v0 = 5 #convection speed
N = 10000 #number of vortices
gammas = 1. #vortex strength RMS (normal distribution)
rscale = 0.1 #vortex size scale (rayleigh distribution parameter)
t0 = -(length / v0 / 2)  #start time for observation of convection
t1 = (length / v0 / 2)   #end time
ts = 0.001 # time step

# %% [markdown]
# ### Set random distribution for vortex location, size and strength
# origin at window center

# %%
vortx = np.random.uniform(low=-length/2,high=length/2,size=N)
vorty = np.random.uniform(low=-height/2,high=height/2,size=N)
vortX = np.vstack((vortx,vorty))
gamma = np.random.normal(scale=gammas,size=N)
rho = np.random.rayleigh(scale=rscale,size=N)

# %% [markdown]
# ### Solver/time-stepper

# %%
t = np.arange(t0,t1,ts) # number of time-steps

# %%
A = [] # empty array to store cl value after each iteration
for i in range(len(t)):
    print "this is the iteration {} / {}".format(i, len(t))
    i = i * ts * v0
    obsx = q_mid[:,0] + (length/2)
    obsx = (obsx - i )
    obsy = q_mid[:,1]
    obsX = np.vstack((obsx,obsy))
    dist = obsX[:,:,np.newaxis]-vortX[:,np.newaxis,:] # dim 2 x timesteps x N
    r = np.sqrt((dist*dist).sum(0)) # dim timesteps x N
    utheta = 16 * gamma * (rho**(-3)) * np.exp(-8*(rho**(-4)) * r**2) * (3-(16 * (rho**(-4)) * r**2)) * r   # Mexican-hat shape
    uind = utheta * dist[::-1] # dim 2 x timesteps x N
    uind[0] *= -1 # change sign for ux (to get correct rotation)
    utot = uind.sum(2) # dim 2 x timesteps
    q_newx = q[:,0] + (length/2)
    q_newx = q_newx - i
    q_newy = q[:,1]
    q = np.array([q_newx, q_newy]).T
    dq = np.diff(q, axis=0)
    numpanels = dq.shape[0]
    lengths = np.linalg.norm(dq, axis=1) 
    normals = np.transpose(np.array([dq[:,1], -dq[:,0]]) / lengths)
    tangents = -np.transpose(np.array([dq[:,0], dq[:,1]]) / lengths)
    utot_tangent = utot.T * tangents
    utot_tangent_magnitude = pow((pow(utot_tangent[:,0],2) + pow(utot_tangent[:,1],2)), 0.5)
    cp = (1 - ((utot_tangent_magnitude**2)/v0**2))
    cp = cp * normals[:,1]
    cl = cp.sum(0)
    A.append(cl)
# Out:
# this is the iteration 0 / 20000
# this is the iteration 1 / 20000
# this is the iteration 2 / 20000
# this is the iteration 3 / 20000
# this is the iteration 4 / 20000
# this is the iteration 5 / 20000
# this is the iteration 6 / 20000
# this is the iteration 7 / 20000
# this is the iteration 8 / 20000
# this is the iteration 9 / 20000
# this is the iteration 10 / 20000
# this is the iteration 11 / 20000
# this is the iteration 12 / 20000
# this is the iteration 13 / 20000
# this is the iteration 14 / 20000
# this is the iteration 15 / 20000
# this is the iteration 16 / 20000
# this is the iteration 17 / 20000
# this is the iteration 18 / 20000
# this is the iteration 19 / 20000
# this is the iteration 20 / 20000
# this is the iteration 21 / 20000
# this is the iteration 22 / 20000
# this is the iteration 23 / 20000
# this is the iteration 24 / 20000
# this is the iteration 25 / 20000
# this is the iteration 26 / 20000
# this is the iteration 27 / 20000
# this is the iteration 28 / 20000
# this is the iteration 29 / 20000
# this is the iteration 30 / 20000
# this is the iteration 31 / 20000
# this is the iteration 32 / 20000
# this is the iteration 33 / 20000
# this is the iteration 34 / 20000
# this is the iteration 35 / 20000
# this is the iteration 36 / 20000
# this is the iteration 37 / 20000
# this is the iteration 38 / 20000
# this is the iteration 39 / 20000
# this is the iteration 40 / 20000
# this is the iteration 41 / 20000
# this is the iteration 42 / 20000
# this is the iteration 43 / 20000
# this is the iteration 44 / 20000
# this is the iteration 45 / 20000
# this is the iteration 46 / 20000
# this is the iteration 47 / 20000
# this is the iteration 48 / 20000
# this is the iteration 49 / 20000
# this is the iteration 50 / 20000
# this is the iteration 51 / 20000
# this is the iteration 52 / 20000
# this is the iteration 53 / 20000
# this is the iteration 54 / 20000
# this is the iteration 55 / 20000
# this is the iteration 56 / 20000
# this is the iteration 57 / 20000
# this is the iteration 58 / 20000
# this is the iteration 59 / 20000
# this is the iteration 60 / 20000
# this is the iteration 61 / 20000
# this is the iteration 62 / 20000
# this is the iteration 63 / 20000
# this is the iteration 64 / 20000
# this is the iteration 65 / 20000
# this is the iteration 66 / 20000
# this is the iteration 67 / 20000
# this is the iteration 68 / 20000
# this is the iteration 69 / 20000
# this is the iteration 70 / 20000
# this is the iteration 71 / 20000
# this is the iteration 72 / 20000
# this is the iteration 73 / 20000
# this is the iteration 74 / 20000
# this is the iteration 75 / 20000
# this is the iteration 76 / 20000
# this is the iteration 77 / 20000
# this is the iteration 78 / 20000
# this is the iteration 79 / 20000
# this is the iteration 80 / 20000
# this is the iteration 81 / 20000
# this is the iteration 82 / 20000
# this is the iteration 83 / 20000
# this is the iteration 84 / 20000
# this is the iteration 85 / 20000
# this is the iteration 86 / 20000
# this is the iteration 87 / 20000
# this is the iteration 88 / 20000
# this is the iteration 89 / 20000
# this is the iteration 90 / 20000
# this is the iteration 91 / 20000
# this is the iteration 92 / 20000
# this is the iteration 93 / 20000
# this is the iteration 94 / 20000
# this is the iteration 95 / 20000
# this is the iteration 96 / 20000
# this is the iteration 97 / 20000
# this is the iteration 98 / 20000
# this is the iteration 99 / 20000
# this is the iteration 100 / 20000
# this is the iteration 101 / 20000
# this is the iteration 102 / 20000
# this is the iteration 103 / 20000
# this is the iteration 104 / 20000
# this is the iteration 105 / 20000
# this is the iteration 106 / 20000
# this is the iteration 107 / 20000
# this is the iteration 108 / 20000
# this is the iteration 109 / 20000
# this is the iteration 110 / 20000
# this is the iteration 111 / 20000
# this is the iteration 112 / 20000
# this is the iteration 113 / 20000
# this is the iteration 114 / 20000
# this is the iteration 115 / 20000
# this is the iteration 116 / 20000
# this is the iteration 117 / 20000
# this is the iteration 118 / 20000
# this is the iteration 119 / 20000
# this is the iteration 120 / 20000
# this is the iteration 121 / 20000
# this is the iteration 122 / 20000
# this is the iteration 123 / 20000
# this is the iteration 124 / 20000
# this is the iteration 125 / 20000
# this is the iteration 126 / 20000
# this is the iteration 127 / 20000
# this is the iteration 128 / 20000
# this is the iteration 129 / 20000
# this is the iteration 130 / 20000
# this is the iteration 131 / 20000
# this is the iteration 132 / 20000
# this is the iteration 133 / 20000
# this is the iteration 134 / 20000
# this is the iteration 135 / 20000
# this is the iteration 136 / 20000
# this is the iteration 137 / 20000
# this is the iteration 138 / 20000
# this is the iteration 139 / 20000
# this is the iteration 140 / 20000
# this is the iteration 141 / 20000
# this is the iteration 142 / 20000
# this is the iteration 143 / 20000
# this is the iteration 144 / 20000
# this is the iteration 145 / 20000
# this is the iteration 146 / 20000
# this is the iteration 147 / 20000
# this is the iteration 148 / 20000
# this is the iteration 149 / 20000
# this is the iteration 150 / 20000
# this is the iteration 151 / 20000
# this is the iteration 152 / 20000
# this is the iteration 153 / 20000
# this is the iteration 154 / 20000
# this is the iteration 155 / 20000
# this is the iteration 156 / 20000
# this is the iteration 157 / 20000
# this is the iteration 158 / 20000
# this is the iteration 159 / 20000
# this is the iteration 160 / 20000
# this is the iteration 161 / 20000
# this is the iteration 162 / 20000
# this is the iteration 163 / 20000
# this is the iteration 164 / 20000
# this is the iteration 165 / 20000
# this is the iteration 166 / 20000
# this is the iteration 167 / 20000
# this is the iteration 168 / 20000
# this is the iteration 169 / 20000
# this is the iteration 170 / 20000
# this is the iteration 171 / 20000
# this is the iteration 172 / 20000
# this is the iteration 173 / 20000
# this is the iteration 174 / 20000
# this is the iteration 175 / 20000
# this is the iteration 176 / 20000
# this is the iteration 177 / 20000
# this is the iteration 178 / 20000
# this is the iteration 179 / 20000
# this is the iteration 180 / 20000
# this is the iteration 181 / 20000
# this is the iteration 182 / 20000
# this is the iteration 183 / 20000
# this is the iteration 184 / 20000
# this is the iteration 185 / 20000
# this is the iteration 186 / 20000
# this is the iteration 187 / 20000
# this is the iteration 188 / 20000
# this is the iteration 189 / 20000
# this is the iteration 190 / 20000
# this is the iteration 191 / 20000
# this is the iteration 192 / 20000
# this is the iteration 193 / 20000
# this is the iteration 194 / 20000
# this is the iteration 195 / 20000
# this is the iteration 196 / 20000
# this is the iteration 197 / 20000
# this is the iteration 198 / 20000
# this is the iteration 199 / 20000
# this is the iteration 200 / 20000
# this is the iteration 201 / 20000
# this is the iteration 202 / 20000
# this is the iteration 203 / 20000
# this is the iteration 204 / 20000
# this is the iteration 205 / 20000
# this is the iteration 206 / 20000
# this is the iteration 207 / 20000
# this is the iteration 208 / 20000
# this is the iteration 209 / 20000
# this is the iteration 210 / 20000
# this is the iteration 211 / 20000
# this is the iteration 212 / 20000
# this is the iteration 213 / 20000
# this is the iteration 214 / 20000
# this is the iteration 215 / 20000
# this is the iteration 216 / 20000
# this is the iteration 217 / 20000
# this is the iteration 218 / 20000
# this is the iteration 219 / 20000
# this is the iteration 220 / 20000
# this is the iteration 221 / 20000
# this is the iteration 222 / 20000
# this is the iteration 223 / 20000
# this is the iteration 224 / 20000
# this is the iteration 225 / 20000
# this is the iteration 226 / 20000
# this is the iteration 227 / 20000
# this is the iteration 228 / 20000
# this is the iteration 229 / 20000
# this is the iteration 230 / 20000
# this is the iteration 231 / 20000
# this is the iteration 232 / 20000
# this is the iteration 233 / 20000
# this is the iteration 234 / 20000
# this is the iteration 235 / 20000
# this is the iteration 236 / 20000
# this is the iteration 237 / 20000
# this is the iteration 238 / 20000
# this is the iteration 239 / 20000
# this is the iteration 240 / 20000
# this is the iteration 241 / 20000
# this is the iteration 242 / 20000
# this is the iteration 243 / 20000
# this is the iteration 244 / 20000
# this is the iteration 245 / 20000
# this is the iteration 246 / 20000
# this is the iteration 247 / 20000
# this is the iteration 248 / 20000
# this is the iteration 249 / 20000
# this is the iteration 250 / 20000
# this is the iteration 251 / 20000
# this is the iteration 252 / 20000
# this is the iteration 253 / 20000
# this is the iteration 254 / 20000
# this is the iteration 255 / 20000
# this is the iteration 256 / 20000
# this is the iteration 257 / 20000
# this is the iteration 258 / 20000
# this is the iteration 259 / 20000
# this is the iteration 260 / 20000
# this is the iteration 261 / 20000
# this is the iteration 262 / 20000
# this is the iteration 263 / 20000
# this is the iteration 264 / 20000
# this is the iteration 265 / 20000
# this is the iteration 266 / 20000
# this is the iteration 267 / 20000
# this is the iteration 268 / 20000
# this is the iteration 269 / 20000
# this is the iteration 270 / 20000
# this is the iteration 271 / 20000
# this is the iteration 272 / 20000
# this is the iteration 273 / 20000
# this is the iteration 274 / 20000
# this is the iteration 275 / 20000
# this is the iteration 276 / 20000
# this is the iteration 277 / 20000
# this is the iteration 278 / 20000
# this is the iteration 279 / 20000
# this is the iteration 280 / 20000
# this is the iteration 281 / 20000
# this is the iteration 282 / 20000
# this is the iteration 283 / 20000
# this is the iteration 284 / 20000
# this is the iteration 285 / 20000
# this is the iteration 286 / 20000
# this is the iteration 287 / 20000
# this is the iteration 288 / 20000
# this is the iteration 289 / 20000
# this is the iteration 290 / 20000
# this is the iteration 291 / 20000
# this is the iteration 292 / 20000
# this is the iteration 293 / 20000
# this is the iteration 294 / 20000
# this is the iteration 295 / 20000
# this is the iteration 296 / 20000
# this is the iteration 297 / 20000
# this is the iteration 298 / 20000
# this is the iteration 299 / 20000
# this is the iteration 300 / 20000
# this is the iteration 301 / 20000
# this is the iteration 302 / 20000
# this is the iteration 303 / 20000
# this is the iteration 304 / 20000
# this is the iteration 305 / 20000
# this is the iteration 306 / 20000
# this is the iteration 307 / 20000
# this is the iteration 308 / 20000
# this is the iteration 309 / 20000
# this is the iteration 310 / 20000
# this is the iteration 311 / 20000
# this is the iteration 312 / 20000
# this is the iteration 313 / 20000
# this is the iteration 314 / 20000
# this is the iteration 315 / 20000
# this is the iteration 316 / 20000
# this is the iteration 317 / 20000
# this is the iteration 318 / 20000
# this is the iteration 319 / 20000
# this is the iteration 320 / 20000
# this is the iteration 321 / 20000
# this is the iteration 322 / 20000
# this is the iteration 323 / 20000
# this is the iteration 324 / 20000
# this is the iteration 325 / 20000
# this is the iteration 326 / 20000
# this is the iteration 327 / 20000
# this is the iteration 328 / 20000
# this is the iteration 329 / 20000
# this is the iteration 330 / 20000
# this is the iteration 331 / 20000
# this is the iteration 332 / 20000
# this is the iteration 333 / 20000
# this is the iteration 334 / 20000
# this is the iteration 335 / 20000
# this is the iteration 336 / 20000
# this is the iteration 337 / 20000
# this is the iteration 338 / 20000
# this is the iteration 339 / 20000
# this is the iteration 340 / 20000
# this is the iteration 341 / 20000
# this is the iteration 342 / 20000
# this is the iteration 343 / 20000
# this is the iteration 344 / 20000
# this is the iteration 345 / 20000
# this is the iteration 346 / 20000
# this is the iteration 347 / 20000
# this is the iteration 348 / 20000
# this is the iteration 349 / 20000
# this is the iteration 350 / 20000
# this is the iteration 351 / 20000
# this is the iteration 352 / 20000
# this is the iteration 353 / 20000
# this is the iteration 354 / 20000
# this is the iteration 355 / 20000
# this is the iteration 356 / 20000
# this is the iteration 357 / 20000
# this is the iteration 358 / 20000
# this is the iteration 359 / 20000
# this is the iteration 360 / 20000
# this is the iteration 361 / 20000
# this is the iteration 362 / 20000
# this is the iteration 363 / 20000
# this is the iteration 364 / 20000
# this is the iteration 365 / 20000
# this is the iteration 366 / 20000
# this is the iteration 367 / 20000
# this is the iteration 368 / 20000
# this is the iteration 369 / 20000
# this is the iteration 370 / 20000
# this is the iteration 371 / 20000
# this is the iteration 372 / 20000
# this is the iteration 373 / 20000
# this is the iteration 374 / 20000
# this is the iteration 375 / 20000
# this is the iteration 376 / 20000
# this is the iteration 377 / 20000
# this is the iteration 378 / 20000
# this is the iteration 379 / 20000
# this is the iteration 380 / 20000
# this is the iteration 381 / 20000
# this is the iteration 382 / 20000
# this is the iteration 383 / 20000
# this is the iteration 384 / 20000
# this is the iteration 385 / 20000
# this is the iteration 386 / 20000
# this is the iteration 387 / 20000
# this is the iteration 388 / 20000
# this is the iteration 389 / 20000
# this is the iteration 390 / 20000
# this is the iteration 391 / 20000
# this is the iteration 392 / 20000
# this is the iteration 393 / 20000
# this is the iteration 394 / 20000
# this is the iteration 395 / 20000
# this is the iteration 396 / 20000
# this is the iteration 397 / 20000
# this is the iteration 398 / 20000
# this is the iteration 399 / 20000
# this is the iteration 400 / 20000
# this is the iteration 401 / 20000
# this is the iteration 402 / 20000
# this is the iteration 403 / 20000
# this is the iteration 404 / 20000
# this is the iteration 405 / 20000
# this is the iteration 406 / 20000
# this is the iteration 407 / 20000
# this is the iteration 408 / 20000
# this is the iteration 409 / 20000
# this is the iteration 410 / 20000
# this is the iteration 411 / 20000
# this is the iteration 412 / 20000
# this is the iteration 413 / 20000
# this is the iteration 414 / 20000
# this is the iteration 415 / 20000
# this is the iteration 416 / 20000
# this is the iteration 417 / 20000
# this is the iteration 418 / 20000
# this is the iteration 419 / 20000
# this is the iteration 420 / 20000
# this is the iteration 421 / 20000
# this is the iteration 422 / 20000
# this is the iteration 423 / 20000
# this is the iteration 424 / 20000
# this is the iteration 425 / 20000
# this is the iteration 426 / 20000
# this is the iteration 427 / 20000
# this is the iteration 428 / 20000
# this is the iteration 429 / 20000
# this is the iteration 430 / 20000
# this is the iteration 431 / 20000
# this is the iteration 432 / 20000
# this is the iteration 433 / 20000
# this is the iteration 434 / 20000
# this is the iteration 435 / 20000
# this is the iteration 436 / 20000
# this is the iteration 437 / 20000
# this is the iteration 438 / 20000
# this is the iteration 439 / 20000
# this is the iteration 440 / 20000
# this is the iteration 441 / 20000
# this is the iteration 442 / 20000
# this is the iteration 443 / 20000
# this is the iteration 444 / 20000
# this is the iteration 445 / 20000
# this is the iteration 446 / 20000
# this is the iteration 447 / 20000
# this is the iteration 448 / 20000
# this is the iteration 449 / 20000
# this is the iteration 450 / 20000
# this is the iteration 451 / 20000
# this is the iteration 452 / 20000
# this is the iteration 453 / 20000
# this is the iteration 454 / 20000
# this is the iteration 455 / 20000
# this is the iteration 456 / 20000
# this is the iteration 457 / 20000
# this is the iteration 458 / 20000
# this is the iteration 459 / 20000
# this is the iteration 460 / 20000
# this is the iteration 461 / 20000
# this is the iteration 462 / 20000
# this is the iteration 463 / 20000
# this is the iteration 464 / 20000
# this is the iteration 465 / 20000
# this is the iteration 466 / 20000
# this is the iteration 467 / 20000
# this is the iteration 468 / 20000
# this is the iteration 469 / 20000
# this is the iteration 470 / 20000
# this is the iteration 471 / 20000
# this is the iteration 472 / 20000
# this is the iteration 473 / 20000
# this is the iteration 474 / 20000
# this is the iteration 475 / 20000
# this is the iteration 476 / 20000
# this is the iteration 477 / 20000
# this is the iteration 478 / 20000
# this is the iteration 479 / 20000
# this is the iteration 480 / 20000
# this is the iteration 481 / 20000
# this is the iteration 482 / 20000
# this is the iteration 483 / 20000
# this is the iteration 484 / 20000
# this is the iteration 485 / 20000
# this is the iteration 486 / 20000
# this is the iteration 487 / 20000
# this is the iteration 488 / 20000
# this is the iteration 489 / 20000
# this is the iteration 490 / 20000
# this is the iteration 491 / 20000
# this is the iteration 492 / 20000
# this is the iteration 493 / 20000
# this is the iteration 494 / 20000
# this is the iteration 495 / 20000
# this is the iteration 496 / 20000
# this is the iteration 497 / 20000
# this is the iteration 498 / 20000
# this is the iteration 499 / 20000
# this is the iteration 500 / 20000
# this is the iteration 501 / 20000
# this is the iteration 502 / 20000
# this is the iteration 503 / 20000
# this is the iteration 504 / 20000
# this is the iteration 505 / 20000
# this is the iteration 506 / 20000
# this is the iteration 507 / 20000
# this is the iteration 508 / 20000
# this is the iteration 509 / 20000
# this is the iteration 510 / 20000
# this is the iteration 511 / 20000
# this is the iteration 512 / 20000
# this is the iteration 513 / 20000
# this is the iteration 514 / 20000
# this is the iteration 515 / 20000
# this is the iteration 516 / 20000
# this is the iteration 517 / 20000
# this is the iteration 518 / 20000
# this is the iteration 519 / 20000
# this is the iteration 520 / 20000
# this is the iteration 521 / 20000
# this is the iteration 522 / 20000
# this is the iteration 523 / 20000
# this is the iteration 524 / 20000
# this is the iteration 525 / 20000
# this is the iteration 526 / 20000
# this is the iteration 527 / 20000
# this is the iteration 528 / 20000
# this is the iteration 529 / 20000
# this is the iteration 530 / 20000
# this is the iteration 531 / 20000
# this is the iteration 532 / 20000
# this is the iteration 533 / 20000
# this is the iteration 534 / 20000
# this is the iteration 535 / 20000
# this is the iteration 536 / 20000
# this is the iteration 537 / 20000
# this is the iteration 538 / 20000
# this is the iteration 539 / 20000
# this is the iteration 540 / 20000
# this is the iteration 541 / 20000
# this is the iteration 542 / 20000
# this is the iteration 543 / 20000
# this is the iteration 544 / 20000
# this is the iteration 545 / 20000
# this is the iteration 546 / 20000
# this is the iteration 547 / 20000
# this is the iteration 548 / 20000
# this is the iteration 549 / 20000
# this is the iteration 550 / 20000
# this is the iteration 551 / 20000
# this is the iteration 552 / 20000
# this is the iteration 553 / 20000
# this is the iteration 554 / 20000
# this is the iteration 555 / 20000
# this is the iteration 556 / 20000
# this is the iteration 557 / 20000
# this is the iteration 558 / 20000
# this is the iteration 559 / 20000
# this is the iteration 560 / 20000
# this is the iteration 561 / 20000
# this is the iteration 562 / 20000
# this is the iteration 563 / 20000
# this is the iteration 564 / 20000
# this is the iteration 565 / 20000
# this is the iteration 566 / 20000
# this is the iteration 567 / 20000
# this is the iteration 568 / 20000
# this is the iteration 569 / 20000
# this is the iteration 570 / 20000
# this is the iteration 571 / 20000
# this is the iteration 572 / 20000
# this is the iteration 573 / 20000
# this is the iteration 574 / 20000
# this is the iteration 575 / 20000
# this is the iteration 576 / 20000
# this is the iteration 577 / 20000
# this is the iteration 578 / 20000
# this is the iteration 579 / 20000
# this is the iteration 580 / 20000
# this is the iteration 581 / 20000
# this is the iteration 582 / 20000
# this is the iteration 583 / 20000
# this is the iteration 584 / 20000
# this is the iteration 585 / 20000
# this is the iteration 586 / 20000
# this is the iteration 587 / 20000
# this is the iteration 588 / 20000
# this is the iteration 589 / 20000
# this is the iteration 590 / 20000
# this is the iteration 591 / 20000
# this is the iteration 592 / 20000
# this is the iteration 593 / 20000
# this is the iteration 594 / 20000
# this is the iteration 595 / 20000
# this is the iteration 596 / 20000
# this is the iteration 597 / 20000
# this is the iteration 598 / 20000
# this is the iteration 599 / 20000
# this is the iteration 600 / 20000
# this is the iteration 601 / 20000
# this is the iteration 602 / 20000
# this is the iteration 603 / 20000
# this is the iteration 604 / 20000
# this is the iteration 605 / 20000
# this is the iteration 606 / 20000
# this is the iteration 607 / 20000
# this is the iteration 608 / 20000
# this is the iteration 609 / 20000
# this is the iteration 610 / 20000
# this is the iteration 611 / 20000
# this is the iteration 612 / 20000
# this is the iteration 613 / 20000
# this is the iteration 614 / 20000
# this is the iteration 615 / 20000
# this is the iteration 616 / 20000
# this is the iteration 617 / 20000
# this is the iteration 618 / 20000
# this is the iteration 619 / 20000
# this is the iteration 620 / 20000
# this is the iteration 621 / 20000
# this is the iteration 622 / 20000
# this is the iteration 623 / 20000
# this is the iteration 624 / 20000
# this is the iteration 625 / 20000
# this is the iteration 626 / 20000
# this is the iteration 627 / 20000
# this is the iteration 628 / 20000
# this is the iteration 629 / 20000
# this is the iteration 630 / 20000
# this is the iteration 631 / 20000
# this is the iteration 632 / 20000
# this is the iteration 633 / 20000
# this is the iteration 634 / 20000
# this is the iteration 635 / 20000
# this is the iteration 636 / 20000
# this is the iteration 637 / 20000
# this is the iteration 638 / 20000
# this is the iteration 639 / 20000
# this is the iteration 640 / 20000
# this is the iteration 641 / 20000
# this is the iteration 642 / 20000
# this is the iteration 643 / 20000
# this is the iteration 644 / 20000
# this is the iteration 645 / 20000
# this is the iteration 646 / 20000
# this is the iteration 647 / 20000
# this is the iteration 648 / 20000
# this is the iteration 649 / 20000
# this is the iteration 650 / 20000
# this is the iteration 651 / 20000
# this is the iteration 652 / 20000
# this is the iteration 653 / 20000
# this is the iteration 654 / 20000
# this is the iteration 655 / 20000
# this is the iteration 656 / 20000
# this is the iteration 657 / 20000
# this is the iteration 658 / 20000
# this is the iteration 659 / 20000
# this is the iteration 660 / 20000
# this is the iteration 661 / 20000
# this is the iteration 662 / 20000
# this is the iteration 663 / 20000
# this is the iteration 664 / 20000
# this is the iteration 665 / 20000
# this is the iteration 666 / 20000
# this is the iteration 667 / 20000
# this is the iteration 668 / 20000
# this is the iteration 669 / 20000
# this is the iteration 670 / 20000
# this is the iteration 671 / 20000
# this is the iteration 672 / 20000
# this is the iteration 673 / 20000
# this is the iteration 674 / 20000
# this is the iteration 675 / 20000
# this is the iteration 676 / 20000
# this is the iteration 677 / 20000
# this is the iteration 678 / 20000
# this is the iteration 679 / 20000
# this is the iteration 680 / 20000
# this is the iteration 681 / 20000
# this is the iteration 682 / 20000
# this is the iteration 683 / 20000
# this is the iteration 684 / 20000
# this is the iteration 685 / 20000
# this is the iteration 686 / 20000
# this is the iteration 687 / 20000
# this is the iteration 688 / 20000
# this is the iteration 689 / 20000
# this is the iteration 690 / 20000
# this is the iteration 691 / 20000
# this is the iteration 692 / 20000
# this is the iteration 693 / 20000
# this is the iteration 694 / 20000
# this is the iteration 695 / 20000
# this is the iteration 696 / 20000
# this is the iteration 697 / 20000
# this is the iteration 698 / 20000
# this is the iteration 699 / 20000
# this is the iteration 700 / 20000
# this is the iteration 701 / 20000
# this is the iteration 702 / 20000
# this is the iteration 703 / 20000
# this is the iteration 704 / 20000
# this is the iteration 705 / 20000
# this is the iteration 706 / 20000
# this is the iteration 707 / 20000
# this is the iteration 708 / 20000
# this is the iteration 709 / 20000
# this is the iteration 710 / 20000
# this is the iteration 711 / 20000
# this is the iteration 712 / 20000
# this is the iteration 713 / 20000
# this is the iteration 714 / 20000
# this is the iteration 715 / 20000
# this is the iteration 716 / 20000
# this is the iteration 717 / 20000
# this is the iteration 718 / 20000
# this is the iteration 719 / 20000
# this is the iteration 720 / 20000
# this is the iteration 721 / 20000
# this is the iteration 722 / 20000
# this is the iteration 723 / 20000
# this is the iteration 724 / 20000
# this is the iteration 725 / 20000
# this is the iteration 726 / 20000
# this is the iteration 727 / 20000
# this is the iteration 728 / 20000
# this is the iteration 729 / 20000
# this is the iteration 730 / 20000
# this is the iteration 731 / 20000
# this is the iteration 732 / 20000
# this is the iteration 733 / 20000
# this is the iteration 734 / 20000
# this is the iteration 735 / 20000
# this is the iteration 736 / 20000
# this is the iteration 737 / 20000
# this is the iteration 738 / 20000
# this is the iteration 739 / 20000
# this is the iteration 740 / 20000
# this is the iteration 741 / 20000
# this is the iteration 742 / 20000
# this is the iteration 743 / 20000
# this is the iteration 744 / 20000
# this is the iteration 745 / 20000
# this is the iteration 746 / 20000
# this is the iteration 747 / 20000
# this is the iteration 748 / 20000
# this is the iteration 749 / 20000
# this is the iteration 750 / 20000
# this is the iteration 751 / 20000
# this is the iteration 752 / 20000
# this is the iteration 753 / 20000
# this is the iteration 754 / 20000
# this is the iteration 755 / 20000
# this is the iteration 756 / 20000
# this is the iteration 757 / 20000
# this is the iteration 758 / 20000
# this is the iteration 759 / 20000
# this is the iteration 760 / 20000
# this is the iteration 761 / 20000
# this is the iteration 762 / 20000
# this is the iteration 763 / 20000
# this is the iteration 764 / 20000
# this is the iteration 765 / 20000
# this is the iteration 766 / 20000
# this is the iteration 767 / 20000
# this is the iteration 768 / 20000
# this is the iteration 769 / 20000
# this is the iteration 770 / 20000
# this is the iteration 771 / 20000
# this is the iteration 772 / 20000
# this is the iteration 773 / 20000
# this is the iteration 774 / 20000
# this is the iteration 775 / 20000
# this is the iteration 776 / 20000
# this is the iteration 777 / 20000
# this is the iteration 778 / 20000
# this is the iteration 779 / 20000
# this is the iteration 780 / 20000
# this is the iteration 781 / 20000
# this is the iteration 782 / 20000
# this is the iteration 783 / 20000
# this is the iteration 784 / 20000
# this is the iteration 785 / 20000
# this is the iteration 786 / 20000
# this is the iteration 787 / 20000
# this is the iteration 788 / 20000
# this is the iteration 789 / 20000
# this is the iteration 790 / 20000
# this is the iteration 791 / 20000
# this is the iteration 792 / 20000
# this is the iteration 793 / 20000
# this is the iteration 794 / 20000
# this is the iteration 795 / 20000
# this is the iteration 796 / 20000
# this is the iteration 797 / 20000
# this is the iteration 798 / 20000
# this is the iteration 799 / 20000
# this is the iteration 800 / 20000
# this is the iteration 801 / 20000
# this is the iteration 802 / 20000
# this is the iteration 803 / 20000
# this is the iteration 804 / 20000
# this is the iteration 805 / 20000
# this is the iteration 806 / 20000
# this is the iteration 807 / 20000
# this is the iteration 808 / 20000
# this is the iteration 809 / 20000
# this is the iteration 810 / 20000
# this is the iteration 811 / 20000
# this is the iteration 812 / 20000
# this is the iteration 813 / 20000
# this is the iteration 814 / 20000
# this is the iteration 815 / 20000
# this is the iteration 816 / 20000
# this is the iteration 817 / 20000
# this is the iteration 818 / 20000
# this is the iteration 819 / 20000
# this is the iteration 820 / 20000
# this is the iteration 821 / 20000
# this is the iteration 822 / 20000
# this is the iteration 823 / 20000
# this is the iteration 824 / 20000
# this is the iteration 825 / 20000
# this is the iteration 826 / 20000
# this is the iteration 827 / 20000
# this is the iteration 828 / 20000
# this is the iteration 829 / 20000
# this is the iteration 830 / 20000
# this is the iteration 831 / 20000
# this is the iteration 832 / 20000
# this is the iteration 833 / 20000
# this is the iteration 834 / 20000
# this is the iteration 835 / 20000
# this is the iteration 836 / 20000
# this is the iteration 837 / 20000
# this is the iteration 838 / 20000
# this is the iteration 839 / 20000
# this is the iteration 840 / 20000
# this is the iteration 841 / 20000
# this is the iteration 842 / 20000
# this is the iteration 843 / 20000
# this is the iteration 844 / 20000
# this is the iteration 845 / 20000
# this is the iteration 846 / 20000
# this is the iteration 847 / 20000
# this is the iteration 848 / 20000
# this is the iteration 849 / 20000
# this is the iteration 850 / 20000
# this is the iteration 851 / 20000
# this is the iteration 852 / 20000
# this is the iteration 853 / 20000
# this is the iteration 854 / 20000
# this is the iteration 855 / 20000
# this is the iteration 856 / 20000
# this is the iteration 857 / 20000
# this is the iteration 858 / 20000
# this is the iteration 859 / 20000
# this is the iteration 860 / 20000
# this is the iteration 861 / 20000
# this is the iteration 862 / 20000
# this is the iteration 863 / 20000
# this is the iteration 864 / 20000
# this is the iteration 865 / 20000
# this is the iteration 866 / 20000
# this is the iteration 867 / 20000
# this is the iteration 868 / 20000
# this is the iteration 869 / 20000
# this is the iteration 870 / 20000
# this is the iteration 871 / 20000
# this is the iteration 872 / 20000
# this is the iteration 873 / 20000
# this is the iteration 874 / 20000
# this is the iteration 875 / 20000
# this is the iteration 876 / 20000
# this is the iteration 877 / 20000
# this is the iteration 878 / 20000
# this is the iteration 879 / 20000
# this is the iteration 880 / 20000
# this is the iteration 881 / 20000
# this is the iteration 882 / 20000
# this is the iteration 883 / 20000
# this is the iteration 884 / 20000
# this is the iteration 885 / 20000
# this is the iteration 886 / 20000
# this is the iteration 887 / 20000
# this is the iteration 888 / 20000
# this is the iteration 889 / 20000
# this is the iteration 890 / 20000
# this is the iteration 891 / 20000
# this is the iteration 892 / 20000
# this is the iteration 893 / 20000
# this is the iteration 894 / 20000
# this is the iteration 895 / 20000
# this is the iteration 896 / 20000
# this is the iteration 897 / 20000
# this is the iteration 898 / 20000
# this is the iteration 899 / 20000
# this is the iteration 900 / 20000
# this is the iteration 901 / 20000
# this is the iteration 902 / 20000
# this is the iteration 903 / 20000
# this is the iteration 904 / 20000
# this is the iteration 905 / 20000
# this is the iteration 906 / 20000
# this is the iteration 907 / 20000
# this is the iteration 908 / 20000
# this is the iteration 909 / 20000
# this is the iteration 910 / 20000
# this is the iteration 911 / 20000
# this is the iteration 912 / 20000
# this is the iteration 913 / 20000
# this is the iteration 914 / 20000
# this is the iteration 915 / 20000
# this is the iteration 916 / 20000
# this is the iteration 917 / 20000
# this is the iteration 918 / 20000
# this is the iteration 919 / 20000
# this is the iteration 920 / 20000
# this is the iteration 921 / 20000
# this is the iteration 922 / 20000
# this is the iteration 923 / 20000
# this is the iteration 924 / 20000
# this is the iteration 925 / 20000
# this is the iteration 926 / 20000
# this is the iteration 927 / 20000
# this is the iteration 928 / 20000
# this is the iteration 929 / 20000
# this is the iteration 930 / 20000
# this is the iteration 931 / 20000
# this is the iteration 932 / 20000
# this is the iteration 933 / 20000
# this is the iteration 934 / 20000
# this is the iteration 935 / 20000
# this is the iteration 936 / 20000
# this is the iteration 937 / 20000
# this is the iteration 938 / 20000
# this is the iteration 939 / 20000
# this is the iteration 940 / 20000
# this is the iteration 941 / 20000
# this is the iteration 942 / 20000
# this is the iteration 943 / 20000
# this is the iteration 944 / 20000
# this is the iteration 945 / 20000
# this is the iteration 946 / 20000
# this is the iteration 947 / 20000
# this is the iteration 948 / 20000
# this is the iteration 949 / 20000
# this is the iteration 950 / 20000
# this is the iteration 951 / 20000
# this is the iteration 952 / 20000
# this is the iteration 953 / 20000
# this is the iteration 954 / 20000
# this is the iteration 955 / 20000
# this is the iteration 956 / 20000
# this is the iteration 957 / 20000
# this is the iteration 958 / 20000
# this is the iteration 959 / 20000
# this is the iteration 960 / 20000
# this is the iteration 961 / 20000
# this is the iteration 962 / 20000
# this is the iteration 963 / 20000
# this is the iteration 964 / 20000
# this is the iteration 965 / 20000
# this is the iteration 966 / 20000
# this is the iteration 967 / 20000
# this is the iteration 968 / 20000
# this is the iteration 969 / 20000
# this is the iteration 970 / 20000
# this is the iteration 971 / 20000
# this is the iteration 972 / 20000
# this is the iteration 973 / 20000
# this is the iteration 974 / 20000
# this is the iteration 975 / 20000
# this is the iteration 976 / 20000
# this is the iteration 977 / 20000
# this is the iteration 978 / 20000
# this is the iteration 979 / 20000
# this is the iteration 980 / 20000
# this is the iteration 981 / 20000
# this is the iteration 982 / 20000
# this is the iteration 983 / 20000
# this is the iteration 984 / 20000
# this is the iteration 985 / 20000
# this is the iteration 986 / 20000
# this is the iteration 987 / 20000
# this is the iteration 988 / 20000
# this is the iteration 989 / 20000
# this is the iteration 990 / 20000
# this is the iteration 991 / 20000
# this is the iteration 992 / 20000
# this is the iteration 993 / 20000
# this is the iteration 994 / 20000
# this is the iteration 995 / 20000
# this is the iteration 996 / 20000
# this is the iteration 997 / 20000
# this is the iteration 998 / 20000
# this is the iteration 999 / 20000
# this is the iteration 1000 / 20000
# this is the iteration 1001 / 20000
# this is the iteration 1002 / 20000
# this is the iteration 1003 / 20000
# this is the iteration 1004 / 20000
# this is the iteration 1005 / 20000
# this is the iteration 1006 / 20000
# this is the iteration 1007 / 20000
# this is the iteration 1008 / 20000
# this is the iteration 1009 / 20000
# this is the iteration 1010 / 20000
# this is the iteration 1011 / 20000
# this is the iteration 1012 / 20000
# this is the iteration 1013 / 20000
# this is the iteration 1014 / 20000
# this is the iteration 1015 / 20000
# this is the iteration 1016 / 20000
# this is the iteration 1017 / 20000
# this is the iteration 1018 / 20000
# this is the iteration 1019 / 20000
# this is the iteration 1020 / 20000
# this is the iteration 1021 / 20000
# this is the iteration 1022 / 20000
# this is the iteration 1023 / 20000
# this is the iteration 1024 / 20000
# this is the iteration 1025 / 20000
# this is the iteration 1026 / 20000
# this is the iteration 1027 / 20000
# this is the iteration 1028 / 20000
# this is the iteration 1029 / 20000
# this is the iteration 1030 / 20000
# this is the iteration 1031 / 20000
# this is the iteration 1032 / 20000
# this is the iteration 1033 / 20000
# this is the iteration 1034 / 20000
# this is the iteration 1035 / 20000
# this is the iteration 1036 / 20000
# this is the iteration 1037 / 20000
# this is the iteration 1038 / 20000
# this is the iteration 1039 / 20000
# this is the iteration 1040 / 20000
# this is the iteration 1041 / 20000
# this is the iteration 1042 / 20000
# this is the iteration 1043 / 20000
# this is the iteration 1044 / 20000
# this is the iteration 1045 / 20000
# this is the iteration 1046 / 20000
# this is the iteration 1047 / 20000
# this is the iteration 1048 / 20000
# this is the iteration 1049 / 20000
# this is the iteration 1050 / 20000
# this is the iteration 1051 / 20000
# this is the iteration 1052 / 20000
# this is the iteration 1053 / 20000
# this is the iteration 1054 / 20000
# this is the iteration 1055 / 20000
# this is the iteration 1056 / 20000
# this is the iteration 1057 / 20000
# this is the iteration 1058 / 20000
# this is the iteration 1059 / 20000
# this is the iteration 1060 / 20000
# this is the iteration 1061 / 20000
# this is the iteration 1062 / 20000
# this is the iteration 1063 / 20000
# this is the iteration 1064 / 20000
# this is the iteration 1065 / 20000
# this is the iteration 1066 / 20000
# this is the iteration 1067 / 20000
# this is the iteration 1068 / 20000
# this is the iteration 1069 / 20000
# this is the iteration 1070 / 20000
# this is the iteration 1071 / 20000
# this is the iteration 1072 / 20000
# this is the iteration 1073 / 20000
# this is the iteration 1074 / 20000
# this is the iteration 1075 / 20000
# this is the iteration 1076 / 20000
# this is the iteration 1077 / 20000
# this is the iteration 1078 / 20000
# this is the iteration 1079 / 20000
# this is the iteration 1080 / 20000
# this is the iteration 1081 / 20000
# this is the iteration 1082 / 20000
# this is the iteration 1083 / 20000
# this is the iteration 1084 / 20000
# this is the iteration 1085 / 20000
# this is the iteration 1086 / 20000
# this is the iteration 1087 / 20000
# this is the iteration 1088 / 20000
# this is the iteration 1089 / 20000
# this is the iteration 1090 / 20000
# this is the iteration 1091 / 20000
# this is the iteration 1092 / 20000
# this is the iteration 1093 / 20000
# this is the iteration 1094 / 20000
# this is the iteration 1095 / 20000
# this is the iteration 1096 / 20000
# this is the iteration 1097 / 20000
# this is the iteration 1098 / 20000
# this is the iteration 1099 / 20000
# this is the iteration 1100 / 20000
# this is the iteration 1101 / 20000
# this is the iteration 1102 / 20000
# this is the iteration 1103 / 20000
# this is the iteration 1104 / 20000
# this is the iteration 1105 / 20000
# this is the iteration 1106 / 20000
# this is the iteration 1107 / 20000
# this is the iteration 1108 / 20000
# this is the iteration 1109 / 20000
# this is the iteration 1110 / 20000
# this is the iteration 1111 / 20000
# this is the iteration 1112 / 20000
# this is the iteration 1113 / 20000
# this is the iteration 1114 / 20000
# this is the iteration 1115 / 20000
# this is the iteration 1116 / 20000
# this is the iteration 1117 / 20000
# this is the iteration 1118 / 20000
# this is the iteration 1119 / 20000
# this is the iteration 1120 / 20000
# this is the iteration 1121 / 20000
# this is the iteration 1122 / 20000
# this is the iteration 1123 / 20000
# this is the iteration 1124 / 20000
# this is the iteration 1125 / 20000
# this is the iteration 1126 / 20000
# this is the iteration 1127 / 20000
# this is the iteration 1128 / 20000
# this is the iteration 1129 / 20000
# this is the iteration 1130 / 20000
# this is the iteration 1131 / 20000
# this is the iteration 1132 / 20000
# this is the iteration 1133 / 20000
# this is the iteration 1134 / 20000
# this is the iteration 1135 / 20000
# this is the iteration 1136 / 20000
# this is the iteration 1137 / 20000
# this is the iteration 1138 / 20000
# this is the iteration 1139 / 20000
# this is the iteration 1140 / 20000
# this is the iteration 1141 / 20000
# this is the iteration 1142 / 20000
# this is the iteration 1143 / 20000
# this is the iteration 1144 / 20000
# this is the iteration 1145 / 20000
# this is the iteration 1146 / 20000
# this is the iteration 1147 / 20000
# this is the iteration 1148 / 20000
# this is the iteration 1149 / 20000
# this is the iteration 1150 / 20000
# this is the iteration 1151 / 20000
# this is the iteration 1152 / 20000
# this is the iteration 1153 / 20000
# this is the iteration 1154 / 20000
# this is the iteration 1155 / 20000
# this is the iteration 1156 / 20000
# this is the iteration 1157 / 20000
# this is the iteration 1158 / 20000
# this is the iteration 1159 / 20000
# this is the iteration 1160 / 20000
# this is the iteration 1161 / 20000
# this is the iteration 1162 / 20000
# this is the iteration 1163 / 20000
# this is the iteration 1164 / 20000
# this is the iteration 1165 / 20000
# this is the iteration 1166 / 20000
# this is the iteration 1167 / 20000
# this is the iteration 1168 / 20000
# this is the iteration 1169 / 20000
# this is the iteration 1170 / 20000
# this is the iteration 1171 / 20000
# this is the iteration 1172 / 20000
# this is the iteration 1173 / 20000
# this is the iteration 1174 / 20000
# this is the iteration 1175 / 20000
# this is the iteration 1176 / 20000
# this is the iteration 1177 / 20000
# this is the iteration 1178 / 20000
# this is the iteration 1179 / 20000
# this is the iteration 1180 / 20000
# this is the iteration 1181 / 20000
# this is the iteration 1182 / 20000
# this is the iteration 1183 / 20000
# this is the iteration 1184 / 20000
# this is the iteration 1185 / 20000
# this is the iteration 1186 / 20000
# this is the iteration 1187 / 20000
# this is the iteration 1188 / 20000
# this is the iteration 1189 / 20000
# this is the iteration 1190 / 20000
# this is the iteration 1191 / 20000
# this is the iteration 1192 / 20000
# this is the iteration 1193 / 20000
# this is the iteration 1194 / 20000
# this is the iteration 1195 / 20000
# this is the iteration 1196 / 20000
# this is the iteration 1197 / 20000
# this is the iteration 1198 / 20000
# this is the iteration 1199 / 20000
# this is the iteration 1200 / 20000
# this is the iteration 1201 / 20000
# this is the iteration 1202 / 20000
# this is the iteration 1203 / 20000
# this is the iteration 1204 / 20000
# this is the iteration 1205 / 20000
# this is the iteration 1206 / 20000
# this is the iteration 1207 / 20000
# this is the iteration 1208 / 20000
# this is the iteration 1209 / 20000
# this is the iteration 1210 / 20000
# this is the iteration 1211 / 20000
# this is the iteration 1212 / 20000
# this is the iteration 1213 / 20000
# this is the iteration 1214 / 20000
# this is the iteration 1215 / 20000
# this is the iteration 1216 / 20000
# this is the iteration 1217 / 20000
# this is the iteration 1218 / 20000
# this is the iteration 1219 / 20000
# this is the iteration 1220 / 20000
# this is the iteration 1221 / 20000
# this is the iteration 1222 / 20000
# this is the iteration 1223 / 20000
# this is the iteration 1224 / 20000
# this is the iteration 1225 / 20000
# this is the iteration 1226 / 20000
# this is the iteration 1227 / 20000
# this is the iteration 1228 / 20000
# this is the iteration 1229 / 20000
# this is the iteration 1230 / 20000
# this is the iteration 1231 / 20000
# this is the iteration 1232 / 20000
# this is the iteration 1233 / 20000
# this is the iteration 1234 / 20000
# this is the iteration 1235 / 20000
# this is the iteration 1236 / 20000
# this is the iteration 1237 / 20000
# this is the iteration 1238 / 20000
# this is the iteration 1239 / 20000
# this is the iteration 1240 / 20000
# this is the iteration 1241 / 20000
# this is the iteration 1242 / 20000
# this is the iteration 1243 / 20000
# this is the iteration 1244 / 20000
# this is the iteration 1245 / 20000
# this is the iteration 1246 / 20000
# this is the iteration 1247 / 20000
# this is the iteration 1248 / 20000
# this is the iteration 1249 / 20000
# this is the iteration 1250 / 20000
# this is the iteration 1251 / 20000
# this is the iteration 1252 / 20000
# this is the iteration 1253 / 20000
# this is the iteration 1254 / 20000
# this is the iteration 1255 / 20000
# this is the iteration 1256 / 20000
# this is the iteration 1257 / 20000
# this is the iteration 1258 / 20000
# this is the iteration 1259 / 20000
# this is the iteration 1260 / 20000
# this is the iteration 1261 / 20000
# this is the iteration 1262 / 20000
# this is the iteration 1263 / 20000
# this is the iteration 1264 / 20000
# this is the iteration 1265 / 20000
# this is the iteration 1266 / 20000
# this is the iteration 1267 / 20000
# this is the iteration 1268 / 20000
# this is the iteration 1269 / 20000
# this is the iteration 1270 / 20000
# this is the iteration 1271 / 20000
# this is the iteration 1272 / 20000
# this is the iteration 1273 / 20000
# this is the iteration 1274 / 20000
# this is the iteration 1275 / 20000
# this is the iteration 1276 / 20000
# this is the iteration 1277 / 20000
# this is the iteration 1278 / 20000
# this is the iteration 1279 / 20000
# this is the iteration 1280 / 20000
# this is the iteration 1281 / 20000
# this is the iteration 1282 / 20000
# this is the iteration 1283 / 20000
# this is the iteration 1284 / 20000
# this is the iteration 1285 / 20000
# this is the iteration 1286 / 20000
# this is the iteration 1287 / 20000
# this is the iteration 1288 / 20000
# this is the iteration 1289 / 20000
# this is the iteration 1290 / 20000
# this is the iteration 1291 / 20000
# this is the iteration 1292 / 20000
# this is the iteration 1293 / 20000
# this is the iteration 1294 / 20000
# this is the iteration 1295 / 20000
# this is the iteration 1296 / 20000
# this is the iteration 1297 / 20000
# this is the iteration 1298 / 20000
# this is the iteration 1299 / 20000
# this is the iteration 1300 / 20000
# this is the iteration 1301 / 20000
# this is the iteration 1302 / 20000
# this is the iteration 1303 / 20000
# this is the iteration 1304 / 20000
# this is the iteration 1305 / 20000
# this is the iteration 1306 / 20000
# this is the iteration 1307 / 20000
# this is the iteration 1308 / 20000
# this is the iteration 1309 / 20000
# this is the iteration 1310 / 20000
# this is the iteration 1311 / 20000
# this is the iteration 1312 / 20000
# this is the iteration 1313 / 20000
# this is the iteration 1314 / 20000
# this is the iteration 1315 / 20000
# this is the iteration 1316 / 20000
# this is the iteration 1317 / 20000
# this is the iteration 1318 / 20000
# this is the iteration 1319 / 20000
# this is the iteration 1320 / 20000
# this is the iteration 1321 / 20000
# this is the iteration 1322 / 20000
# this is the iteration 1323 / 20000
# this is the iteration 1324 / 20000
# this is the iteration 1325 / 20000
# this is the iteration 1326 / 20000
# this is the iteration 1327 / 20000
# this is the iteration 1328 / 20000
# this is the iteration 1329 / 20000
# this is the iteration 1330 / 20000
# this is the iteration 1331 / 20000
# this is the iteration 1332 / 20000
# this is the iteration 1333 / 20000
# this is the iteration 1334 / 20000
# this is the iteration 1335 / 20000
# this is the iteration 1336 / 20000
# this is the iteration 1337 / 20000
# this is the iteration 1338 / 20000
# this is the iteration 1339 / 20000
# this is the iteration 1340 / 20000
# this is the iteration 1341 / 20000
# this is the iteration 1342 / 20000
# this is the iteration 1343 / 20000
# this is the iteration 1344 / 20000
# this is the iteration 1345 / 20000
# this is the iteration 1346 / 20000
# this is the iteration 1347 / 20000
# this is the iteration 1348 / 20000
# this is the iteration 1349 / 20000
# this is the iteration 1350 / 20000
# this is the iteration 1351 / 20000
# this is the iteration 1352 / 20000
# this is the iteration 1353 / 20000
# this is the iteration 1354 / 20000
# this is the iteration 1355 / 20000
# this is the iteration 1356 / 20000
# this is the iteration 1357 / 20000
# this is the iteration 1358 / 20000
# this is the iteration 1359 / 20000
# this is the iteration 1360 / 20000
# this is the iteration 1361 / 20000
# this is the iteration 1362 / 20000
# this is the iteration 1363 / 20000
# this is the iteration 1364 / 20000
# this is the iteration 1365 / 20000
# this is the iteration 1366 / 20000
# this is the iteration 1367 / 20000
# this is the iteration 1368 / 20000
# this is the iteration 1369 / 20000
# this is the iteration 1370 / 20000
# this is the iteration 1371 / 20000
# this is the iteration 1372 / 20000
# this is the iteration 1373 / 20000
# this is the iteration 1374 / 20000
# this is the iteration 1375 / 20000
# this is the iteration 1376 / 20000
# this is the iteration 1377 / 20000
# this is the iteration 1378 / 20000
# this is the iteration 1379 / 20000
# this is the iteration 1380 / 20000
# this is the iteration 1381 / 20000
# this is the iteration 1382 / 20000
# this is the iteration 1383 / 20000
# this is the iteration 1384 / 20000
# this is the iteration 1385 / 20000
# this is the iteration 1386 / 20000
# this is the iteration 1387 / 20000
# this is the iteration 1388 / 20000
# this is the iteration 1389 / 20000
# this is the iteration 1390 / 20000
# this is the iteration 1391 / 20000
# this is the iteration 1392 / 20000
# this is the iteration 1393 / 20000
# this is the iteration 1394 / 20000
# this is the iteration 1395 / 20000
# this is the iteration 1396 / 20000
# this is the iteration 1397 / 20000
# this is the iteration 1398 / 20000
# this is the iteration 1399 / 20000
# this is the iteration 1400 / 20000
# this is the iteration 1401 / 20000
# this is the iteration 1402 / 20000
# ...
# this is the iteration 19556 / 20000
# this is the iteration 19557 / 20000
# this is the iteration 19558 / 20000
# this is the iteration 19559 / 20000
# this is the iteration 19560 / 20000
# this is the iteration 19561 / 20000
# this is the iteration 19562 / 20000
# this is the iteration 19563 / 20000
# this is the iteration 19564 / 20000
# this is the iteration 19565 / 20000
# this is the iteration 19566 / 20000
# this is the iteration 19567 / 20000
# this is the iteration 19568 / 20000
# this is the iteration 19569 / 20000
# this is the iteration 19570 / 20000
# this is the iteration 19571 / 20000
# this is the iteration 19572 / 20000
# this is the iteration 19573 / 20000
# this is the iteration 19574 / 20000
# this is the iteration 19575 / 20000
# this is the iteration 19576 / 20000
# this is the iteration 19577 / 20000
# this is the iteration 19578 / 20000
# this is the iteration 19579 / 20000
# this is the iteration 19580 / 20000
# this is the iteration 19581 / 20000
# this is the iteration 19582 / 20000
# this is the iteration 19583 / 20000
# this is the iteration 19584 / 20000
# this is the iteration 19585 / 20000
# this is the iteration 19586 / 20000
# this is the iteration 19587 / 20000
# this is the iteration 19588 / 20000
# this is the iteration 19589 / 20000
# this is the iteration 19590 / 20000
# this is the iteration 19591 / 20000
# this is the iteration 19592 / 20000
# this is the iteration 19593 / 20000
# this is the iteration 19594 / 20000
# this is the iteration 19595 / 20000
# this is the iteration 19596 / 20000
# this is the iteration 19597 / 20000
# this is the iteration 19598 / 20000
# this is the iteration 19599 / 20000
# this is the iteration 19600 / 20000
# this is the iteration 19601 / 20000
# this is the iteration 19602 / 20000
# this is the iteration 19603 / 20000
# this is the iteration 19604 / 20000
# this is the iteration 19605 / 20000
# this is the iteration 19606 / 20000
# this is the iteration 19607 / 20000
# this is the iteration 19608 / 20000
# this is the iteration 19609 / 20000
# this is the iteration 19610 / 20000
# this is the iteration 19611 / 20000
# this is the iteration 19612 / 20000
# this is the iteration 19613 / 20000
# this is the iteration 19614 / 20000
# this is the iteration 19615 / 20000
# this is the iteration 19616 / 20000
# this is the iteration 19617 / 20000
# this is the iteration 19618 / 20000
# this is the iteration 19619 / 20000
# this is the iteration 19620 / 20000
# this is the iteration 19621 / 20000
# this is the iteration 19622 / 20000
# this is the iteration 19623 / 20000
# this is the iteration 19624 / 20000
# this is the iteration 19625 / 20000
# this is the iteration 19626 / 20000
# this is the iteration 19627 / 20000
# this is the iteration 19628 / 20000
# this is the iteration 19629 / 20000
# this is the iteration 19630 / 20000
# this is the iteration 19631 / 20000
# this is the iteration 19632 / 20000
# this is the iteration 19633 / 20000
# this is the iteration 19634 / 20000
# this is the iteration 19635 / 20000
# this is the iteration 19636 / 20000
# this is the iteration 19637 / 20000
# this is the iteration 19638 / 20000
# this is the iteration 19639 / 20000
# this is the iteration 19640 / 20000
# this is the iteration 19641 / 20000
# this is the iteration 19642 / 20000
# this is the iteration 19643 / 20000
# this is the iteration 19644 / 20000
# this is the iteration 19645 / 20000
# this is the iteration 19646 / 20000
# this is the iteration 19647 / 20000
# this is the iteration 19648 / 20000
# this is the iteration 19649 / 20000
# this is the iteration 19650 / 20000
# this is the iteration 19651 / 20000
# this is the iteration 19652 / 20000
# this is the iteration 19653 / 20000
# this is the iteration 19654 / 20000
# this is the iteration 19655 / 20000
# this is the iteration 19656 / 20000
# this is the iteration 19657 / 20000
# this is the iteration 19658 / 20000
# this is the iteration 19659 / 20000
# this is the iteration 19660 / 20000
# this is the iteration 19661 / 20000
# this is the iteration 19662 / 20000
# this is the iteration 19663 / 20000
# this is the iteration 19664 / 20000
# this is the iteration 19665 / 20000
# this is the iteration 19666 / 20000
# this is the iteration 19667 / 20000
# this is the iteration 19668 / 20000
# this is the iteration 19669 / 20000
# this is the iteration 19670 / 20000
# this is the iteration 19671 / 20000
# this is the iteration 19672 / 20000
# this is the iteration 19673 / 20000
# this is the iteration 19674 / 20000
# this is the iteration 19675 / 20000
# this is the iteration 19676 / 20000
# this is the iteration 19677 / 20000
# this is the iteration 19678 / 20000
# this is the iteration 19679 / 20000
# this is the iteration 19680 / 20000
# this is the iteration 19681 / 20000
# this is the iteration 19682 / 20000
# this is the iteration 19683 / 20000
# this is the iteration 19684 / 20000
# this is the iteration 19685 / 20000
# this is the iteration 19686 / 20000
# this is the iteration 19687 / 20000
# this is the iteration 19688 / 20000
# this is the iteration 19689 / 20000
# this is the iteration 19690 / 20000
# this is the iteration 19691 / 20000
# this is the iteration 19692 / 20000
# this is the iteration 19693 / 20000
# this is the iteration 19694 / 20000
# this is the iteration 19695 / 20000
# this is the iteration 19696 / 20000
# this is the iteration 19697 / 20000
# this is the iteration 19698 / 20000
# this is the iteration 19699 / 20000
# this is the iteration 19700 / 20000
# this is the iteration 19701 / 20000
# this is the iteration 19702 / 20000
# this is the iteration 19703 / 20000
# this is the iteration 19704 / 20000
# this is the iteration 19705 / 20000
# this is the iteration 19706 / 20000
# this is the iteration 19707 / 20000
# this is the iteration 19708 / 20000
# this is the iteration 19709 / 20000
# this is the iteration 19710 / 20000
# this is the iteration 19711 / 20000
# this is the iteration 19712 / 20000
# this is the iteration 19713 / 20000
# this is the iteration 19714 / 20000
# this is the iteration 19715 / 20000
# this is the iteration 19716 / 20000
# this is the iteration 19717 / 20000
# this is the iteration 19718 / 20000
# this is the iteration 19719 / 20000
# this is the iteration 19720 / 20000
# this is the iteration 19721 / 20000
# this is the iteration 19722 / 20000
# this is the iteration 19723 / 20000
# this is the iteration 19724 / 20000
# this is the iteration 19725 / 20000
# this is the iteration 19726 / 20000
# this is the iteration 19727 / 20000
# this is the iteration 19728 / 20000
# this is the iteration 19729 / 20000
# this is the iteration 19730 / 20000
# this is the iteration 19731 / 20000
# this is the iteration 19732 / 20000
# this is the iteration 19733 / 20000
# this is the iteration 19734 / 20000
# this is the iteration 19735 / 20000
# this is the iteration 19736 / 20000
# this is the iteration 19737 / 20000
# this is the iteration 19738 / 20000
# this is the iteration 19739 / 20000
# this is the iteration 19740 / 20000
# this is the iteration 19741 / 20000
# this is the iteration 19742 / 20000
# this is the iteration 19743 / 20000
# this is the iteration 19744 / 20000
# this is the iteration 19745 / 20000
# this is the iteration 19746 / 20000
# this is the iteration 19747 / 20000
# this is the iteration 19748 / 20000
# this is the iteration 19749 / 20000
# this is the iteration 19750 / 20000
# this is the iteration 19751 / 20000
# this is the iteration 19752 / 20000
# this is the iteration 19753 / 20000
# this is the iteration 19754 / 20000
# this is the iteration 19755 / 20000
# this is the iteration 19756 / 20000
# this is the iteration 19757 / 20000
# this is the iteration 19758 / 20000
# this is the iteration 19759 / 20000
# this is the iteration 19760 / 20000
# this is the iteration 19761 / 20000
# this is the iteration 19762 / 20000
# this is the iteration 19763 / 20000
# this is the iteration 19764 / 20000
# this is the iteration 19765 / 20000
# this is the iteration 19766 / 20000
# this is the iteration 19767 / 20000
# this is the iteration 19768 / 20000
# this is the iteration 19769 / 20000
# this is the iteration 19770 / 20000
# this is the iteration 19771 / 20000
# this is the iteration 19772 / 20000
# this is the iteration 19773 / 20000
# this is the iteration 19774 / 20000
# this is the iteration 19775 / 20000
# this is the iteration 19776 / 20000
# this is the iteration 19777 / 20000
# this is the iteration 19778 / 20000
# this is the iteration 19779 / 20000
# this is the iteration 19780 / 20000
# this is the iteration 19781 / 20000
# this is the iteration 19782 / 20000
# this is the iteration 19783 / 20000
# this is the iteration 19784 / 20000
# this is the iteration 19785 / 20000
# this is the iteration 19786 / 20000
# this is the iteration 19787 / 20000
# this is the iteration 19788 / 20000
# this is the iteration 19789 / 20000
# this is the iteration 19790 / 20000
# this is the iteration 19791 / 20000
# this is the iteration 19792 / 20000
# this is the iteration 19793 / 20000
# this is the iteration 19794 / 20000
# this is the iteration 19795 / 20000
# this is the iteration 19796 / 20000
# this is the iteration 19797 / 20000
# this is the iteration 19798 / 20000
# this is the iteration 19799 / 20000
# this is the iteration 19800 / 20000
# this is the iteration 19801 / 20000
# this is the iteration 19802 / 20000
# this is the iteration 19803 / 20000
# this is the iteration 19804 / 20000
# this is the iteration 19805 / 20000
# this is the iteration 19806 / 20000
# this is the iteration 19807 / 20000
# this is the iteration 19808 / 20000
# this is the iteration 19809 / 20000
# this is the iteration 19810 / 20000
# this is the iteration 19811 / 20000
# this is the iteration 19812 / 20000
# this is the iteration 19813 / 20000
# this is the iteration 19814 / 20000
# this is the iteration 19815 / 20000
# this is the iteration 19816 / 20000
# this is the iteration 19817 / 20000
# this is the iteration 19818 / 20000
# this is the iteration 19819 / 20000
# this is the iteration 19820 / 20000
# this is the iteration 19821 / 20000
# this is the iteration 19822 / 20000
# this is the iteration 19823 / 20000
# this is the iteration 19824 / 20000
# this is the iteration 19825 / 20000
# this is the iteration 19826 / 20000
# this is the iteration 19827 / 20000
# this is the iteration 19828 / 20000
# this is the iteration 19829 / 20000
# this is the iteration 19830 / 20000
# this is the iteration 19831 / 20000
# this is the iteration 19832 / 20000
# this is the iteration 19833 / 20000
# this is the iteration 19834 / 20000
# this is the iteration 19835 / 20000
# this is the iteration 19836 / 20000
# this is the iteration 19837 / 20000
# this is the iteration 19838 / 20000
# this is the iteration 19839 / 20000
# this is the iteration 19840 / 20000
# this is the iteration 19841 / 20000
# this is the iteration 19842 / 20000
# this is the iteration 19843 / 20000
# this is the iteration 19844 / 20000
# this is the iteration 19845 / 20000
# this is the iteration 19846 / 20000
# this is the iteration 19847 / 20000
# this is the iteration 19848 / 20000
# this is the iteration 19849 / 20000
# this is the iteration 19850 / 20000
# this is the iteration 19851 / 20000
# this is the iteration 19852 / 20000
# this is the iteration 19853 / 20000
# this is the iteration 19854 / 20000
# this is the iteration 19855 / 20000
# this is the iteration 19856 / 20000
# this is the iteration 19857 / 20000
# this is the iteration 19858 / 20000
# this is the iteration 19859 / 20000
# this is the iteration 19860 / 20000
# this is the iteration 19861 / 20000
# this is the iteration 19862 / 20000
# this is the iteration 19863 / 20000
# this is the iteration 19864 / 20000
# this is the iteration 19865 / 20000
# this is the iteration 19866 / 20000
# this is the iteration 19867 / 20000
# this is the iteration 19868 / 20000
# this is the iteration 19869 / 20000
# this is the iteration 19870 / 20000
# this is the iteration 19871 / 20000
# this is the iteration 19872 / 20000
# this is the iteration 19873 / 20000
# this is the iteration 19874 / 20000
# this is the iteration 19875 / 20000
# this is the iteration 19876 / 20000
# this is the iteration 19877 / 20000
# this is the iteration 19878 / 20000
# this is the iteration 19879 / 20000
# this is the iteration 19880 / 20000
# this is the iteration 19881 / 20000
# this is the iteration 19882 / 20000
# this is the iteration 19883 / 20000
# this is the iteration 19884 / 20000
# this is the iteration 19885 / 20000
# this is the iteration 19886 / 20000
# this is the iteration 19887 / 20000
# this is the iteration 19888 / 20000
# this is the iteration 19889 / 20000
# this is the iteration 19890 / 20000
# this is the iteration 19891 / 20000
# this is the iteration 19892 / 20000
# this is the iteration 19893 / 20000
# this is the iteration 19894 / 20000
# this is the iteration 19895 / 20000
# this is the iteration 19896 / 20000
# this is the iteration 19897 / 20000
# this is the iteration 19898 / 20000
# this is the iteration 19899 / 20000
# this is the iteration 19900 / 20000
# this is the iteration 19901 / 20000
# this is the iteration 19902 / 20000
# this is the iteration 19903 / 20000
# this is the iteration 19904 / 20000
# this is the iteration 19905 / 20000
# this is the iteration 19906 / 20000
# this is the iteration 19907 / 20000
# this is the iteration 19908 / 20000
# this is the iteration 19909 / 20000
# this is the iteration 19910 / 20000
# this is the iteration 19911 / 20000
# this is the iteration 19912 / 20000
# this is the iteration 19913 / 20000
# this is the iteration 19914 / 20000
# this is the iteration 19915 / 20000
# this is the iteration 19916 / 20000
# this is the iteration 19917 / 20000
# this is the iteration 19918 / 20000
# this is the iteration 19919 / 20000
# this is the iteration 19920 / 20000
# this is the iteration 19921 / 20000
# this is the iteration 19922 / 20000
# this is the iteration 19923 / 20000
# this is the iteration 19924 / 20000
# this is the iteration 19925 / 20000
# this is the iteration 19926 / 20000
# this is the iteration 19927 / 20000
# this is the iteration 19928 / 20000
# this is the iteration 19929 / 20000
# this is the iteration 19930 / 20000
# this is the iteration 19931 / 20000
# this is the iteration 19932 / 20000
# this is the iteration 19933 / 20000
# this is the iteration 19934 / 20000
# this is the iteration 19935 / 20000
# this is the iteration 19936 / 20000
# this is the iteration 19937 / 20000
# this is the iteration 19938 / 20000
# this is the iteration 19939 / 20000
# this is the iteration 19940 / 20000
# this is the iteration 19941 / 20000
# this is the iteration 19942 / 20000
# this is the iteration 19943 / 20000
# this is the iteration 19944 / 20000
# this is the iteration 19945 / 20000
# this is the iteration 19946 / 20000
# this is the iteration 19947 / 20000
# this is the iteration 19948 / 20000
# this is the iteration 19949 / 20000
# this is the iteration 19950 / 20000
# this is the iteration 19951 / 20000
# this is the iteration 19952 / 20000
# this is the iteration 19953 / 20000
# this is the iteration 19954 / 20000
# this is the iteration 19955 / 20000
# this is the iteration 19956 / 20000
# this is the iteration 19957 / 20000
# this is the iteration 19958 / 20000
# this is the iteration 19959 / 20000
# this is the iteration 19960 / 20000
# this is the iteration 19961 / 20000
# this is the iteration 19962 / 20000
# this is the iteration 19963 / 20000
# this is the iteration 19964 / 20000
# this is the iteration 19965 / 20000
# this is the iteration 19966 / 20000
# this is the iteration 19967 / 20000
# this is the iteration 19968 / 20000
# this is the iteration 19969 / 20000
# this is the iteration 19970 / 20000
# this is the iteration 19971 / 20000
# this is the iteration 19972 / 20000
# this is the iteration 19973 / 20000
# this is the iteration 19974 / 20000
# this is the iteration 19975 / 20000
# this is the iteration 19976 / 20000
# this is the iteration 19977 / 20000
# this is the iteration 19978 / 20000
# this is the iteration 19979 / 20000
# this is the iteration 19980 / 20000
# this is the iteration 19981 / 20000
# this is the iteration 19982 / 20000
# this is the iteration 19983 / 20000
# this is the iteration 19984 / 20000
# this is the iteration 19985 / 20000
# this is the iteration 19986 / 20000
# this is the iteration 19987 / 20000
# this is the iteration 19988 / 20000
# this is the iteration 19989 / 20000
# this is the iteration 19990 / 20000
# this is the iteration 19991 / 20000
# this is the iteration 19992 / 20000
# this is the iteration 19993 / 20000
# this is the iteration 19994 / 20000
# this is the iteration 19995 / 20000
# this is the iteration 19996 / 20000
# this is the iteration 19997 / 20000
# this is the iteration 19998 / 20000
# this is the iteration 19999 / 20000

# %% [markdown]
# #### Unsteady lift

# %%
A = np.array(A)

# %% [markdown]
# ### Curle's analogy to obtain p' at a distance of 1 unit at theta=90 deg

# %%
def Curles_loadingNoise(y_int,c_sound,r_dist,L,dt,Velo):
    p_acoustic = (((y_int*L)/(4*np.pi*dt*c_sound*(r_dist**2)))*(0.5*1.225*pow(Velo,2)))
    return p_acoustic

noise = Curles_loadingNoise(1,343,1,np.abs(A),ts,v0)
H = ((noise)/(2.e-5))**2

# %% [markdown]
# ### Plot unsteady lift on the airfoil and the SPL in far-field

# %%
plt.figure(1)
plt.subplot(1,2,1)
plt.plot(t,A,label='cl')
plt.title('Unsteady coefficient of lift')
plt.xlabel('time, s')
plt.ylabel('cl')
plt.legend()
plt.subplot(1,2,2)
(val, freq) = psd(H, NFFT=512,Fs=1/ts,detrend='mean')
plt.semilogx(freq,10*np.log10(val),label='SPL')
plt.title('Sound Pressure Level (dB)')
plt.xlabel('Frequency')
plt.ylabel('SPL, dB')
plt.legend()
plt.savefig('cl_SPL.pdf')
plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show>
